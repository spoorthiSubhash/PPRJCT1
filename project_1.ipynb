# %%
import pandas as pd
data=pd.read_csv("usedcars.csv")
data
data.isnull().sum()

from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['model']= label_encoder.fit_transform(data['model'])
data['model'].unique()
data['color']= label_encoder.fit_transform(data['color'])
data['color'].unique()
data['transmission']= label_encoder.fit_transform(data['transmission'])
data['transmission'].unique()
inputs=data.drop('price','columns')
inputs
output=data.drop(['year','model','mileage','color','transmission'],'columns')
output
import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(inputs,output,test_size=0.25)
import sklearn
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(x_train,y_train)
res=model.predict(x_test)
res
x_train
x_test
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11600\3779162480.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs=data.drop('price','columns')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11600\3779162480.py:16: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   output=data.drop(['year','model','mileage','color','transmission'],'columns')
#      year  model  mileage  color  transmission
# 35   2010      1    33036      0             0
# 118  2007      2    77231      5             0
# 18   2011      1    11662      1             0
# 23   2010      1    24920      0             0
# 147  2000      0    96841      5             0
# 17   2010      2    36049      6             0
# 31   2009      0    34419      0             1
# 103  2009      0    32559      0             1
# ...

# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'project1.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import*


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(610, 583)
        Form.setStyleSheet("background-color: qconicalgradient(cx:0, cy:0, angle:135, stop:0 rgba(255, 255, 0, 69), stop:0.375 rgba(255, 255, 0, 69), stop:0.423533 rgba(251, 255, 0, 145), stop:0.45 rgba(247, 255, 0, 208), stop:0.477581 rgba(255, 244, 71, 130), stop:0.518717 rgba(255, 218, 71, 130), stop:0.55 rgba(255, 255, 0, 255), stop:0.57754 rgba(255, 203, 0, 130), stop:0.625 rgba(255, 255, 0, 69), stop:1 rgba(255, 255, 0, 69));")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(90, 10, 441, 31))
        self.label.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 24pt \"MS Shell Dlg 2\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(20, 80, 351, 31))
        self.label_2.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(20, 140, 251, 31))
        self.label_3.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(20, 210, 261, 21))
        self.label_4.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(20, 280, 291, 21))
        self.label_5.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(20, 345, 291, 31))
        self.label_6.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.label_6.setObjectName("label_6")
        self.year = QtWidgets.QLineEdit(Form)
        self.year.setGeometry(QtCore.QRect(370, 79, 201, 31))
        self.year.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Shell Dlg 2\";")
        self.year.setObjectName("year")
        self.model = QtWidgets.QLineEdit(Form)
        self.model.setGeometry(QtCore.QRect(370, 129, 201, 31))
        self.model.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Shell Dlg 2\";")
        self.model.setObjectName("model")
        self.mileage = QtWidgets.QLineEdit(Form)
        self.mileage.setGeometry(QtCore.QRect(370, 199, 201, 31))
        self.mileage.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Shell Dlg 2\";")
        self.mileage.setObjectName("mileage")
        self.color = QtWidgets.QLineEdit(Form)
        self.color.setGeometry(QtCore.QRect(370, 269, 201, 31))
        self.color.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Shell Dlg 2\";")
        self.color.setObjectName("color")
        self.transmission = QtWidgets.QLineEdit(Form)
        self.transmission.setGeometry(QtCore.QRect(370, 339, 201, 31))
        self.transmission.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Shell Dlg 2\";")
        self.transmission.setObjectName("transmission")
        self.predict = QtWidgets.QPushButton(Form)
        self.predict.setGeometry(QtCore.QRect(270, 400, 111, 41))
        self.predict.setObjectName("predict")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(20, 475, 281, 31))
        self.label_7.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 16pt \"MS Shell Dlg 2\";")
        self.label_7.setObjectName("label_7")
        self.result = QtWidgets.QLineEdit(Form)
        self.result.setGeometry(QtCore.QRect(310, 459, 271, 41))
        self.result.setStyleSheet("color: rgb(0, 0, 0);\n"
"font: 75 14pt \"MS Shell Dlg 2\";")
        self.result.setObjectName("result")
        self.predict.clicked.connect(self.used_car)
        
        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
    
    def used_car(self):
        year=self.year.text()
        model=self.model.text()
        mileage=self.mileage.text()
        color=self.color.text()
        transmission=self.transmission.text()
        import pandas as pd
        data=pd.read_csv("usedcars.csv")
        data
        data.isnull().sum()
        
        from sklearn import preprocessing
        label_encoder = preprocessing.LabelEncoder()
        data['model']= label_encoder.fit_transform(data['model'])
        data['model'].unique()
        data['color']= label_encoder.fit_transform(data['color'])
        data['color'].unique()
        data['transmission']= label_encoder.fit_transform(data['transmission'])
        data['transmission'].unique()
        inputs=data.drop('price','columns')
        inputs
        output=data.drop(['year','model','mileage','color','transmission'],'columns')
        output
        import sklearn
        from sklearn.model_selection import train_test_split
        x_train,x_test,y_train,y_test= train_test_split(inputs,output,test_size=0.25)
        import sklearn
        from sklearn import linear_model
        Model=linear_model.LinearRegression()
        Model.fit(x_train,y_train)
        res=Model.predict([[int(year),int(model),int(mileage),int(color),int(transmission)]])
        self.result.setText(str(res))
        
    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "USED CAR PRICE PREDICTION"))
        self.label_2.setText(_translate("Form", "ENTER YEAR OF CAR PURCHASED :-"))
        self.label_3.setText(_translate("Form", "ENTER MODEL OF CAR :-"))
        self.label_4.setText(_translate("Form", "ENTER MILEAGE OF CAR :-"))
        self.label_5.setText(_translate("Form", "ENTER THE COLOR OF CAR :-"))
        self.label_6.setText(_translate("Form", "ENTER THE TRANSMISSION :-"))
        self.predict.setText(_translate("Form", "predict"))
        self.label_7.setText(_translate("Form", "ENTER THE PRICE OF CAR :-"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10124\3689251729.py:112: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs=data.drop('price','columns')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10124\3689251729.py:114: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   output=data.drop(['year','model','mileage','color','transmission'],'columns')
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
